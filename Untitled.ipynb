# %%
run simple_iLQRtest.py
# Out:
# Reference cost = 9.22e+03
#   0%|          | 0/100 [00:00<?, ?it/s]
# iLQR converged after 11 iterations with cost 8.75e+03.

# %%
run springdamper_iLQRtest.py
# Out:
# Reference cost = 4.59e+03
#   0%|          | 0/400 [00:00<?, ?it/s]
# WARNING: Sub-optimal output. iLQR failed to converge. Terminal λ value is 1000.0000000000001 with best-cost-so-far 2.14e+02
