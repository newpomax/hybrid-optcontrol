# %%
run simple_iLQRtest.py
# Out:
# Reference cost = inf
#   0%|          | 0/50 [00:00<?, ?it/s]
# iLQR converged after 43 iterations with cost 1.63e+02.

# %%
run springdamper_iLQRtest.py
# Out:
# Reference cost = inf
#   0%|          | 0/400 [00:00<?, ?it/s]
# iLQR converged after 26 iterations with cost 1.73e+05.
